# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from sklearn.neighbors import KernelDensity
from sklearn.model_selection import KFold
from sklearn.metrics import (accuracy_score, confusion_matrix, ConfusionMatrixDisplay,
                             classification_report, precision_score, f1_score, recall_score)
from scipy.spatial.distance import euclidean
from joblib import Parallel, delayed
from IPython.display import clear_output

# Custom modules
import Functions.dataFrameTools as dataFrameTools
import Functions.processGen as processGen

# Model import
from parametricVAE import dVAE
import SVMClassifier
import latentKDEClassifier
# Reload after changes
from importlib import reload
reload(SVMClassifier)
reload(latentKDEClassifier)

# Access the class
from SVMClassifier import SVMClassifier
from latentKDEClassifier import LatentKDEClassifier

# %% [markdown]
# ### Fetch all datasets

# %%
temp =pd.read_csv("../data/clip_sBIKED_reduced.csv", index_col=0)
temp.shape
# Out:
# (4512, 71)

# %%
###### Fetch all ratings across all groups ######
rated_bikes_df = pd.read_csv('ratings/combined_clean_ratings.csv')


###### Import BIKED visually reduced dataset ######

dfn = dataFrameTools.normalizeDF(0).astype('float32')
visual_df =pd.read_csv("../data/clip_sBIKED_reduced.csv", index_col=0)
columns_to_drop = [col for col in visual_df.columns if 'color' in col]
visual_df.drop(columns=columns_to_drop, inplace=True)
boolean_columns = visual_df.select_dtypes(include=['bool']).columns
visual_df[boolean_columns] = visual_df[boolean_columns].astype(int)
visual_df = visual_df.sort_index(axis=1)
visual_df = visual_df.select_dtypes(include=['number'])
constant_columns = [col for col in visual_df.columns if visual_df[col].nunique() == 1]
visual_df = visual_df.drop(columns=constant_columns)



###### Split rated bikes to usable/unusable ######

threshold_usable = 0.7
threshold_unusable = 1- threshold_usable

average_ratings = rated_bikes_df.groupby('bid')['rating'].mean()
usable_bikes = visual_df.loc[average_ratings[average_ratings >= threshold_usable].index]
unusable_bikes = visual_df.loc[average_ratings[average_ratings <= threshold_unusable].index]
meaningfull_bikes_df = pd.concat([usable_bikes, unusable_bikes])
meaningfull_bikes_df['usable'] = meaningfull_bikes_df.index.isin(usable_bikes.index).astype(int)

usable_ids = meaningfull_bikes_df[meaningfull_bikes_df['usable'] == True].index.tolist()
unusable_ids = meaningfull_bikes_df[meaningfull_bikes_df['usable'] == False].index.tolist()

usable_bikes = dfn.loc[usable_ids] 
unusable_bikes = dfn.loc[unusable_ids] 



##### Import Train and Test Sets ######

input_folder = 'datasets'

X_test = pd.read_csv(os.path.join(input_folder,'X_test.csv'), index_col=0)
y_test = pd.read_csv(os.path.join(input_folder,'y_test.csv'), index_col=0)
X_train = pd.read_csv(os.path.join(input_folder,'X_train.csv'), index_col=0)
y_train = pd.read_csv(os.path.join(input_folder,'y_train.csv'), index_col=0)

X_test_dfn = dfn.loc[X_test.index]
X_train_dfn = dfn.loc[X_train.index]

usable_bikes_train_df = X_train[y_train['usable'] == 1]
unusable_bikes_train_df = X_train[y_train['usable'] == 0]

usable_bikes_test_df = X_test[y_test['usable'] == 1]
unusable_bikes_test_df = X_test[y_test['usable'] == 0]

usable_bikes_test_dfn = dfn.loc[usable_bikes_test_df.index]
usable_bikes_train_dfn = dfn.loc[usable_bikes_train_df.index]
unusable_bikes_test_dfn = dfn.loc[unusable_bikes_test_df.index]
unusable_bikes_train_dfn = dfn.loc[unusable_bikes_train_df.index]
# Out:
# Loaded Imputed Dataframe in  1.9930005073547363 seconds

# %%
dfn.shape
# Out:
# (4512, 2395)

# %% [markdown]
# ### Build VAE and get latent representations of usable/unusable bikes

# %%
ddims = 2395
tuned_VAE_name = 'augmented_VAE'

dataVAE_model =dVAE(ddims, 128, 0.1, 1e-3)
dataVAE_mean = dataVAE_model.build_vae_keras_model_mean()
dataVAE_mean.load_weights('model weights/dataVAE.h5')
encoder_mean =  dataVAE_mean.get_layer('encoder')
decoder_mean =  dataVAE_mean.get_layer('decoder')

tunedVAE=dVAE(ddims, 128, 0.1, 1e-3).build_vae_keras_model_mean()
tunedVAE.load_weights(f'model weights/{tuned_VAE_name}.h5')
tuned_decoder =  tunedVAE.get_layer('decoder')
tuned_encoder_mean =  tunedVAE.get_layer('encoder')

usable_bikes = dfn.loc[usable_ids] 
unusable_bikes = dfn.loc[unusable_ids] 
encoder = tuned_encoder_mean
decoder = tuned_decoder

latent_usable = encoder.predict(usable_bikes)
latent_unusable = encoder.predict(unusable_bikes)

latent_usable_test = encoder.predict(usable_bikes_test_dfn)
latent_usable_train = encoder.predict(usable_bikes_train_dfn)
latent_unusable_test = encoder.predict(unusable_bikes_test_dfn)
latent_unusable_train = encoder.predict(unusable_bikes_train_dfn)
clear_output(wait=False)

# %% [markdown]
# ### Fit KDEs

# %%
def calculate_log_likelihoods_with_cross_validation(bandwidths_usable, bandwidths_unusable, 
                                                    latent_usable_train, latent_unusable_train, 
                                                    n_splits=10, show_report = False):
    
    def calculate_log_odds(dataset, kde):
        log_odds = []
        for point in dataset:
            point = np.reshape(point, (1, -1))  # Ensure correct shape
            log_likelihood = kde.score_samples(point)
            log_odds.append(log_likelihood)
        return log_odds

    best_bandwidth_usable = None
    best_bandwidth_unusable = None
    best_accuracy = -np.inf
    best_preds = []
    best_y_preds = []
    for bw_usable in bandwidths_usable:
        for bw_unusable in bandwidths_unusable:

            accuracies = []
            # Define cross-validation strategy
            kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

            all_preds = []
            all_y_val = []

            # Cross-validation loop
            for (train_usable_idx, val_usable_idx), (train_unusable_idx, val_unusable_idx) in zip(kf.split(latent_usable_train), kf.split(latent_unusable_train)):
                # Fit the KDE models on the training data
                kde_usable = KernelDensity(kernel='gaussian', bandwidth=bw_usable)
                kde_usable.fit(latent_usable_train[train_usable_idx])
                
                kde_unusable = KernelDensity(kernel='gaussian', bandwidth=bw_unusable)
                kde_unusable.fit(latent_unusable_train[train_unusable_idx])

                # Concatenate the validation set (usable + unusable)
                val_set = np.concatenate([latent_usable_train[val_usable_idx], latent_unusable_train[val_unusable_idx]])

                # Create the corresponding labels for the validation set (1 for usable, 0 for unusable)
                y_val = np.concatenate([np.ones(len(val_usable_idx)), np.zeros(len(val_unusable_idx))])

                # Calculate log-odds for both KDEs on the validation set
                log_odds_usable = calculate_log_odds(val_set, kde_usable)
                log_odds_unusable = calculate_log_odds(val_set, kde_unusable)

                # Generate predictions based on log-odds comparison
                preds = [1 if log_odds_usable[i] > log_odds_unusable[i] else 0 
                            for i in range(len(log_odds_usable))]

                # Calculate accuracy of this fold
                accuracy = accuracy_score(y_val, preds)  # Compare predictions with true labels
                # accuracy = f1_score(y_val, preds)
                accuracies.append(accuracy)

                # Append the predictions and true labels for confusion matrix
                all_preds.extend(preds)
                all_y_val.extend(y_val)


            # Return the mean accuracy for this combination of bandwidths
            mean_accuracy =  np.mean(accuracies)

            if mean_accuracy > best_accuracy:
                best_accuracy = mean_accuracy
                best_bandwidth_usable = bw_usable
                best_bandwidth_unusable = bw_unusable
                best_preds = all_preds
                best_y_preds = all_y_val

    
    if show_report:
        cm = confusion_matrix(best_y_preds, best_preds)
        ConfusionMatrixDisplay(cm, display_labels=["Unusable", "Usable"]).plot()
        report = classification_report(best_y_preds, best_preds, target_names=["Unusable", "Usable"])
        print(report)

    return best_bandwidth_usable, best_bandwidth_unusable, best_accuracy

# %% [markdown]
# ## Building SVM Classifier

# %%
features = ['Saddle height', 'Stack', 'CS textfield']
column_indices_to_keep = [unusable_bikes_train_dfn.columns.get_loc(col) for col in features]

X_feature = X_train_dfn[features].values  
y_train_series = y_train['usable']
svm_clf = SVMClassifier(kernel='poly',C = 600, coef0 = 10, degree= 2, gamma='scale', scaler=1000)
svm_clf.fit(X_feature, y_train_series)

# %% [markdown]
# ### Filter poorly represented designs

# %%
latent_kde_classifier = None
features = ['Saddle height', 'Stack', 'CS textfield']
column_indices_to_keep = [unusable_bikes_train_dfn.columns.get_loc(col) for col in features]

latent_unusable_train_filtered = np.empty((0, latent_usable_train.shape[1]))
unusable_bids = []
for bid in unusable_bikes_train_df.index:
    bike = unusable_bikes.loc[[bid]]
    latent = tuned_encoder_mean.predict(bike)[0]
    bike_features_point = (tf.math.sigmoid(tuned_decoder.predict(np.array([latent]))).numpy())[0][column_indices_to_keep]
    pred_svm = svm_clf.predict(bike_features_point.reshape(1, -1))[0]

    if pred_svm == 0:
        latent_unusable_train_filtered = np.append(latent_unusable_train_filtered, [latent], axis=0)
        unusable_bids.append(bid)


latent_usable_train_filtered = np.empty((0, latent_usable_train.shape[1]))
usable_bids = []
for bid in usable_bikes_train_df.index:
    bike = usable_bikes.loc[[bid]]
    latent = tuned_encoder_mean.predict(bike)[0]
    bike_features_point = (tf.math.sigmoid(tuned_decoder.predict(np.array([latent]))).numpy())[0][column_indices_to_keep]
    pred_svm = svm_clf.predict(bike_features_point.reshape(1, -1))[0]

    if pred_svm == 1:
        latent_usable_train_filtered = np.append(latent_usable_train_filtered, [latent], axis=0)
        usable_bids.append(bid)


clear_output(False)


print(len(latent_usable_train_filtered))
print(len(latent_unusable_train_filtered))


usable_bikes_train_filtered_dfn = usable_bikes_train_dfn.loc[usable_bids]
unusable_bikes_train_filtered_dfn = unusable_bikes_train_dfn.loc[unusable_bids]

# Define the range of bandwidths to test for both KDEs
bandwidths_usable = [i*0.01 + 0.2 for i in range(20)]   # Bandwidths for usable KDE  0.2 - 0.4 with step 0.01
bandwidths_unusable = [i*0.01 + 0.2 for i in range(20)]  # Bandwidths for unusable KDE 0.2 - 0.4 with step 0.01

# Calculate the best bandwidths
best_bandwidth_usable, best_bandwidth_unusable, best_accuracy = calculate_log_likelihoods_with_cross_validation(
    bandwidths_usable,
    bandwidths_unusable,
    latent_usable_train_filtered,
    latent_unusable_train_filtered,
)

print("Best bandwidth for usable KDE:", best_bandwidth_usable)
print("Best bandwidth for unusable KDE:", best_bandwidth_unusable)
print("Best accuracy:", best_accuracy)

latent_kde_classifier = LatentKDEClassifier(best_bandwidth_usable, best_bandwidth_unusable)
latent_kde_classifier.fit(latent_usable_train_filtered, latent_unusable_train_filtered)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 34
# 32
# Best bandwidth for usable KDE: 0.36
# Best bandwidth for unusable KDE: 0.32
# Best accuracy: 0.7422619047619048

# %% [markdown]
# ### Perform linear and guided interpolation methods

# %%
def linear_interpolation(point1, point2, div_by):
    # Points 1 and 2 are returned with the array

    interpolated_points = []
    point1 = np.array(point1)
    point2 = np.array(point2)
    
    direction = (point2 - point1) / div_by
    current_point = point1  
    
    for _ in range(div_by + 1):
        interpolated_points.append(current_point)
        current_point = current_point + direction

    return np.array(interpolated_points)

# %%
unusable_bikes_test_df.index.tolist()
# Out:
# [1246, 1771, 2635, 2087, 2738, 4094, 4696, 3927, 1383, 3012]

# %%
import latentKDEClassifier

# Reload after changes
from importlib import reload
reload(latentKDEClassifier)

# Access the class
from latentKDEClassifier import LatentKDEClassifier

latent_kde_classifier = LatentKDEClassifier(best_bandwidth_usable, best_bandwidth_unusable, min_confidence_usable=20)
latent_kde_classifier.fit(latent_usable_train_filtered, latent_unusable_train_filtered)

# %%
latent_kde_classifier.set_min_usable_confidence(None)

bikes_indices = [8,5]
latet_int_bikes = latent_unusable_test[bikes_indices]

# linear_interpolated_points = linear_interpolation(latet_int_bikes[0], latet_int_bikes[1], div_by=10)
# new_points = latent_kde_classifier.move_points(linear_interpolated_points, step_scale=0.1, use_direction = 3, max_iter = 10, verbose=True)



max_iters = [5, 10]  # List of max_iter values to test
distances_linear = []
distances_guided_all = {max_iter: [] for max_iter in max_iters}
guided_points_all = {max_iter: [] for max_iter in max_iters}

counts = {max_iter: 0 for max_iter in max_iters}

# Calculate the linear interpolation points once
linear_interpolated_points = linear_interpolation(latet_int_bikes[0], latet_int_bikes[1], div_by=10)

for i in range(len(linear_interpolated_points)):
    linear_point = linear_interpolated_points[i]

    # Linear point
    bike_features_point_linear = (tf.math.sigmoid(tuned_decoder.predict(np.array([linear_point]))).numpy())[0][column_indices_to_keep]
    pred_svm = svm_clf.predict(bike_features_point_linear.reshape(1, -1))[0]
    distance_linear = svm_clf.distance_to_boundary(bike_features_point_linear) * (-1 if pred_svm else 1)
    distances_linear.append(distance_linear)

# Loop over different max_iter values for the guided points
for max_iter in max_iters:
    new_points = latent_kde_classifier.move_points(linear_interpolated_points, step_scale=0.1, use_direction=3, max_iter=max_iter, verbose=True)
    
    # Calculate distances for each guided point
    for i in range(len(new_points)):
        linear_point = linear_interpolated_points[i]
        guided_point = new_points[i]

        # Guided point
        bike_features_point_guided = (tf.math.sigmoid(tuned_decoder.predict(np.array([guided_point]))).numpy())[0][column_indices_to_keep]
        pred_svm = svm_clf.predict(bike_features_point_guided.reshape(1, -1))[0]
        distance_guided = svm_clf.distance_to_boundary(bike_features_point_guided) * (-1 if pred_svm else 1)
        distances_guided_all[max_iter].append(distance_guided)
        guided_points_all[max_iter].append(guided_point)


        if distance_guided <= distance_linear:
            counts[max_iter] += 1

# Plotting
x_indices = np.arange(len(linear_interpolated_points))  # Indices for the x-axis

plt.figure(figsize=(10, 6))

# Plot the linear distances only once (fixed bar position)
plt.bar(x_indices - 0.2, distances_linear, width=0.2, label="Linear", color='skyblue')

# Plot the guided distances for each max_iter value with sufficient spacing
bar_width = 0.2
for idx, max_iter in enumerate(max_iters):
    # Adjust the offset for each set of bars to avoid overlap
    plt.bar(x_indices + (idx * bar_width), distances_guided_all[max_iter], width=bar_width, label=f"Guided: Max Iteration = {max_iter}", color=plt.cm.Set2(idx / len(max_iters)))

plt.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)  # Decision boundary

plt.xlabel("Design Index")
plt.ylabel("Distance to Decision Boundary")
plt.title("Comparison of Distances to SVM Decision Boundary for Different Max Iteration Values")
plt.legend()
plt.grid(alpha=0.3)
plt.xticks(x_indices, [f"Design {i}" for i in x_indices], rotation=45)
plt.tight_layout()
plt.show()

# Output counts for each max_iter value
for max_iter in max_iters:
    print(f'Number of designs that are closer to usable with max_iter={max_iter}: {counts[max_iter]}')
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Point 0: Starting adjustment
# Point 0, Step 0: log_likelihood_usable=[-7.32819857], log_likelihood_unusable=[5.23568663]
# Point 0, Step 1: log_likelihood_usable=[-6.31882516], log_likelihood_unusable=[3.95857792]
# Point 0, Step 2: log_likelihood_usable=[-5.36903607], log_likelihood_unusable=[2.96350112]
# Point 0, Step 3: log_likelihood_usable=[-4.67641201], log_likelihood_unusable=[2.72675631]
# Point 0, Step 4: log_likelihood_usable=[-4.17878584], log_likelihood_unusable=[2.22551]
# Point 0: Did not converge within 5 steps, final log_likelihoods - usable=[-3.67579297], unusable=[1.72311427]
# Point 1: Starting adjustment
# Point 1, Step 0: log_likelihood_usable=[-6.47363111], log_likelihood_unusable=[6.33385125]
# Point 1, Step 1: log_likelihood_usable=[-5.54262497], log_likelihood_unusable=[5.58098681]
# Point 1, Step 2: log_likelihood_usable=[-4.93969802], log_likelihood_unusable=[5.36575182]
# Point 1, Step 3: log_likelihood_usable=[-4.46092062], log_likelihood_unusable=[4.95643445]
# Point 1, Step 4: log_likelihood_usable=[-3.96639444], log_likelihood_unusable=[4.56336421]
# Point 1: Did not converge within 5 steps, final log_likelihoods - usable=[-3.47307255], unusable=[4.11272825]
# Point 2: Starting adjustment
# Point 2, Step 0: log_likelihood_usable=[-7.46404957], log_likelihood_unusable=[6.25313723]
# Point 2, Step 1: log_likelihood_usable=[-6.88426656], log_likelihood_unusable=[5.85084348]
# Point 2, Step 2: log_likelihood_usable=[-6.42262891], log_likelihood_unusable=[5.59137228]
# Point 2, Step 3: log_likelihood_usable=[-5.99181723], log_likelihood_unusable=[5.2618812]
# Point 2, Step 4: log_likelihood_usable=[-5.52967581], log_likelihood_unusable=[4.94834076]
# Point 2: Did not converge within 5 steps, final log_likelihoods - usable=[-5.06958422], unusable=[4.5483187]
# Point 3: Starting adjustment
# Point 3, Step 0: log_likelihood_usable=[-9.67795022], log_likelihood_unusable=[5.81069876]
# Point 3, Step 1: log_likelihood_usable=[-8.70241293], log_likelihood_unusable=[4.76849507]
# Point 3, Step 2: log_likelihood_usable=[-7.58769767], log_likelihood_unusable=[3.82615377]
# Point 3, Step 3: log_likelihood_usable=[-6.5152492], log_likelihood_unusable=[3.04861029]
# Point 3, Step 4: log_likelihood_usable=[-5.5438416], log_likelihood_unusable=[2.24652168]
# Point 3: Did not converge within 5 steps, final log_likelihoods - usable=[-4.62317832], unusable=[1.3980046]
# Point 4: Starting adjustment
# Point 4, Step 0: log_likelihood_usable=[-9.17760559], log_likelihood_unusable=[3.3508427]
# Point 4, Step 1: log_likelihood_usable=[-7.97361585], log_likelihood_unusable=[1.82127909]
# Point 4, Step 2: log_likelihood_usable=[-6.80821962], log_likelihood_unusable=[0.34430253]
# Point 4, Step 3: log_likelihood_usable=[-5.70256424], log_likelihood_unusable=[-0.83137353]
# Point 4, Step 4: log_likelihood_usable=[-4.74143767], log_likelihood_unusable=[-0.97478692]
# Point 4: Did not converge within 5 steps, final log_likelihoods - usable=[-4.10937036], unusable=[-1.0373332]
# Point 5: Starting adjustment
# Point 5, Step 0: log_likelihood_usable=[-8.82665015], log_likelihood_unusable=[1.38984013]
# Point 5, Step 1: log_likelihood_usable=[-7.77674061], log_likelihood_unusable=[0.25937676]
# Point 5, Step 2: log_likelihood_usable=[-6.71351436], log_likelihood_unusable=[-0.49065317]
# Point 5, Step 3: log_likelihood_usable=[-5.73174829], log_likelihood_unusable=[-0.76625841]
# Point 5, Step 4: log_likelihood_usable=[-4.97141275], log_likelihood_unusable=[-1.15546228]
# Point 5: Did not converge within 5 steps, final log_likelihoods - usable=[-4.07590568], unusable=[-1.28206018]
# Point 6: Starting adjustment
# Point 6, Step 0: log_likelihood_usable=[-8.9599079], log_likelihood_unusable=[3.92235876]
# Point 6, Step 1: log_likelihood_usable=[-8.0025843], log_likelihood_unusable=[2.65296834]
# Point 6, Step 2: log_likelihood_usable=[-7.07154308], log_likelihood_unusable=[1.44976575]
# Point 6, Step 3: log_likelihood_usable=[-6.1853824], log_likelihood_unusable=[0.4527508]
# Point 6, Step 4: log_likelihood_usable=[-5.35178797], log_likelihood_unusable=[-0.50069549]
# Point 6: Did not converge within 5 steps, final log_likelihoods - usable=[-4.54664496], unusable=[-1.34235114]
# Point 7: Starting adjustment
# Point 7, Step 0: log_likelihood_usable=[-10.23133436], log_likelihood_unusable=[4.3176068]
# Point 7, Step 1: log_likelihood_usable=[-9.24080869], log_likelihood_unusable=[3.14507616]
# Point 7, Step 2: log_likelihood_usable=[-8.27031585], log_likelihood_unusable=[1.97867143]
# Point 7, Step 3: log_likelihood_usable=[-7.32045652], log_likelihood_unusable=[0.87285908]
# Point 7, Step 4: log_likelihood_usable=[-6.38227166], log_likelihood_unusable=[-0.18016898]
# Point 7: Did not converge within 5 steps, final log_likelihoods - usable=[-5.44593765], unusable=[-1.25075481]
# Point 8: Starting adjustment
# Point 8, Step 0: log_likelihood_usable=[-12.90807958], log_likelihood_unusable=[5.34030116]
# Point 8, Step 1: log_likelihood_usable=[-11.54512014], log_likelihood_unusable=[3.91027065]
# Point 8, Step 2: log_likelihood_usable=[-10.24459871], log_likelihood_unusable=[2.59978378]
# Point 8, Step 3: log_likelihood_usable=[-9.05312013], log_likelihood_unusable=[1.39776053]
# Point 8, Step 4: log_likelihood_usable=[-7.97074963], log_likelihood_unusable=[0.17402366]
# Point 8: Did not converge within 5 steps, final log_likelihoods - usable=[-6.95671329], unusable=[-1.0818349]
# Point 9: Starting adjustment
# Point 9, Step 0: log_likelihood_usable=[-17.23679581], log_likelihood_unusable=[5.98504003]
# Point 9, Step 1: log_likelihood_usable=[-15.78323269], log_likelihood_unusable=[4.55111421]
# Point 9, Step 2: log_likelihood_usable=[-14.3645313], log_likelihood_unusable=[3.0798594]
# Point 9, Step 3: log_likelihood_usable=[-12.98479985], log_likelihood_unusable=[1.59368391]
# Point 9, Step 4: log_likelihood_usable=[-11.6492051], log_likelihood_unusable=[0.12187847]
# Point 9: Did not converge within 5 steps, final log_likelihoods - usable=[-10.3676538], unusable=[-1.29980555]
# Point 10: Starting adjustment
# Point 10, Step 0: log_likelihood_usable=[-23.35499392], log_likelihood_unusable=[5.33518785]
# Point 10, Step 1: log_likelihood_usable=[-21.90346627], log_likelihood_unusable=[4.18500062]
# Point 10, Step 2: log_likelihood_usable=[-20.47091401], log_likelihood_unusable=[2.98724585]
# Point 10, Step 3: log_likelihood_usable=[-19.0602458], log_likelihood_unusable=[1.73820261]
# Point 10, Step 4: log_likelihood_usable=[-17.6744477], log_likelihood_unusable=[0.4380385]
# Point 10: Did not converge within 5 steps, final log_likelihoods - usable=[-16.31627551], unusable=[-0.91044247]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Point 0: Starting adjustment
# Point 0, Step 0: log_likelihood_usable=[-7.32819857], log_likelihood_unusable=[5.23568663]
# Point 0, Step 1: log_likelihood_usable=[-6.31882516], log_likelihood_unusable=[3.95857792]
# Point 0, Step 2: log_likelihood_usable=[-5.36903607], log_likelihood_unusable=[2.96350112]
# Point 0, Step 3: log_likelihood_usable=[-4.67641201], log_likelihood_unusable=[2.72675631]
# Point 0, Step 4: log_likelihood_usable=[-4.17878584], log_likelihood_unusable=[2.22551]
# Point 0, Step 5: log_likelihood_usable=[-3.67579297], log_likelihood_unusable=[1.72311427]
# Point 0, Step 6: log_likelihood_usable=[-3.17811941], log_likelihood_unusable=[1.18797373]
# Point 0, Step 7: log_likelihood_usable=[-2.68327764], log_likelihood_unusable=[0.63351599]
# Point 0, Step 8: log_likelihood_usable=[-2.19472607], log_likelihood_unusable=[0.05786632]
# Point 0, Step 9: log_likelihood_usable=[-1.7143914], log_likelihood_unusable=[-0.53696419]
# Point 0: Did not converge within 10 steps, final log_likelihoods - usable=[-1.24429544], unusable=[-1.14942748]
# Point 1: Starting adjustment
# Point 1, Step 0: log_likelihood_usable=[-6.47363111], log_likelihood_unusable=[6.33385125]
# Point 1, Step 1: log_likelihood_usable=[-5.54262497], log_likelihood_unusable=[5.58098681]
# Point 1, Step 2: log_likelihood_usable=[-4.93969802], log_likelihood_unusable=[5.36575182]
# Point 1, Step 3: log_likelihood_usable=[-4.46092062], log_likelihood_unusable=[4.95643445]
# Point 1, Step 4: log_likelihood_usable=[-3.96639444], log_likelihood_unusable=[4.56336421]
# Point 1, Step 5: log_likelihood_usable=[-3.47307255], log_likelihood_unusable=[4.11272825]
# Point 1, Step 6: log_likelihood_usable=[-2.96863552], log_likelihood_unusable=[3.64861367]
# Point 1, Step 7: log_likelihood_usable=[-2.4651393], log_likelihood_unusable=[3.14986364]
# Point 1, Step 8: log_likelihood_usable=[-1.96157698], log_likelihood_unusable=[2.62834123]
# Point 1, Step 9: log_likelihood_usable=[-1.46269734], log_likelihood_unusable=[2.0812118]
# Point 1: Did not converge within 10 steps, final log_likelihoods - usable=[-0.97087203], unusable=[1.51094957]
# Point 2: Starting adjustment
# Point 2, Step 0: log_likelihood_usable=[-7.46404957], log_likelihood_unusable=[6.25313723]
# Point 2, Step 1: log_likelihood_usable=[-6.88426656], log_likelihood_unusable=[5.85084348]
# Point 2, Step 2: log_likelihood_usable=[-6.42262891], log_likelihood_unusable=[5.59137228]
# Point 2, Step 3: log_likelihood_usable=[-5.99181723], log_likelihood_unusable=[5.2618812]
# Point 2, Step 4: log_likelihood_usable=[-5.52967581], log_likelihood_unusable=[4.94834076]
# Point 2, Step 5: log_likelihood_usable=[-5.06958422], log_likelihood_unusable=[4.5483187]
# Point 2, Step 6: log_likelihood_usable=[-4.58876986], log_likelihood_unusable=[4.15237446]
# Point 2, Step 7: log_likelihood_usable=[-4.10775929], log_likelihood_unusable=[3.69956757]
# Point 2, Step 8: log_likelihood_usable=[-3.61391109], log_likelihood_unusable=[3.23520034]
# Point 2, Step 9: log_likelihood_usable=[-3.11758093], log_likelihood_unusable=[2.73802327]
# Point 2: Did not converge within 10 steps, final log_likelihoods - usable=[-2.61862455], unusable=[2.21899318]
# Point 3: Starting adjustment
# Point 3, Step 0: log_likelihood_usable=[-9.67795022], log_likelihood_unusable=[5.81069876]
# Point 3, Step 1: log_likelihood_usable=[-8.70241293], log_likelihood_unusable=[4.76849507]
# Point 3, Step 2: log_likelihood_usable=[-7.58769767], log_likelihood_unusable=[3.82615377]
# Point 3, Step 3: log_likelihood_usable=[-6.5152492], log_likelihood_unusable=[3.04861029]
# Point 3, Step 4: log_likelihood_usable=[-5.5438416], log_likelihood_unusable=[2.24652168]
# Point 3, Step 5: log_likelihood_usable=[-4.62317832], log_likelihood_unusable=[1.3980046]
# Point 3, Step 6: log_likelihood_usable=[-3.73850763], log_likelihood_unusable=[0.52500097]
# Point 3, Step 7: log_likelihood_usable=[-2.89054445], log_likelihood_unusable=[-0.18855384]
# Point 3, Step 8: log_likelihood_usable=[-2.19034994], log_likelihood_unusable=[-0.15882616]
# Point 3, Step 9: log_likelihood_usable=[-1.54746738], log_likelihood_unusable=[-0.22665827]
# Point 3: Did not converge within 10 steps, final log_likelihoods - usable=[-0.85088282], unusable=[-0.22035896]
# Point 4: Starting adjustment
# Point 4, Step 0: log_likelihood_usable=[-9.17760559], log_likelihood_unusable=[3.3508427]
# Point 4, Step 1: log_likelihood_usable=[-7.97361585], log_likelihood_unusable=[1.82127909]
# Point 4, Step 2: log_likelihood_usable=[-6.80821962], log_likelihood_unusable=[0.34430253]
# Point 4, Step 3: log_likelihood_usable=[-5.70256424], log_likelihood_unusable=[-0.83137353]
# Point 4, Step 4: log_likelihood_usable=[-4.74143767], log_likelihood_unusable=[-0.97478692]
# Point 4, Step 5: log_likelihood_usable=[-4.10937036], log_likelihood_unusable=[-1.0373332]
# Point 4, Step 6: log_likelihood_usable=[-3.36161543], log_likelihood_unusable=[-0.90755833]
# Point 4, Step 7: log_likelihood_usable=[-2.73057565], log_likelihood_unusable=[-1.0755879]
# Point 4, Step 8: log_likelihood_usable=[-2.06319116], log_likelihood_unusable=[-1.01374408]
# Point 4, Step 9: log_likelihood_usable=[-1.45736152], log_likelihood_unusable=[-1.23530625]
# Point 4: Did not converge within 10 steps, final log_likelihoods - usable=[-0.83025439], unusable=[-1.25235969]
# Point 5: Starting adjustment
# Point 5, Step 0: log_likelihood_usable=[-8.82665015], log_likelihood_unusable=[1.38984013]
# Point 5, Step 1: log_likelihood_usable=[-7.77674061], log_likelihood_unusable=[0.25937676]
# Point 5, Step 2: log_likelihood_usable=[-6.71351436], log_likelihood_unusable=[-0.49065317]
# Point 5, Step 3: log_likelihood_usable=[-5.73174829], log_likelihood_unusable=[-0.76625841]
# Point 5, Step 4: log_likelihood_usable=[-4.97141275], log_likelihood_unusable=[-1.15546228]
# Point 5, Step 5: log_likelihood_usable=[-4.07590568], log_likelihood_unusable=[-1.28206018]
# Point 5, Step 6: log_likelihood_usable=[-3.35137432], log_likelihood_unusable=[-1.77400443]
# Point 5, Step 7: log_likelihood_usable=[-2.6057296], log_likelihood_unusable=[-1.9096367]
# Point 5: Adjustment complete after 8 steps, final log_likelihoods - usable=[-1.99973174], unusable=[-2.1545068]
# Point 6: Starting adjustment
# Point 6, Step 0: log_likelihood_usable=[-8.9599079], log_likelihood_unusable=[3.92235876]
# Point 6, Step 1: log_likelihood_usable=[-8.0025843], log_likelihood_unusable=[2.65296834]
# Point 6, Step 2: log_likelihood_usable=[-7.07154308], log_likelihood_unusable=[1.44976575]
# Point 6, Step 3: log_likelihood_usable=[-6.1853824], log_likelihood_unusable=[0.4527508]
# Point 6, Step 4: log_likelihood_usable=[-5.35178797], log_likelihood_unusable=[-0.50069549]
# Point 6, Step 5: log_likelihood_usable=[-4.54664496], log_likelihood_unusable=[-1.34235114]
# Point 6, Step 6: log_likelihood_usable=[-3.7903736], log_likelihood_unusable=[-1.80359844]
# Point 6, Step 7: log_likelihood_usable=[-2.98716935], log_likelihood_unusable=[-2.21781042]
# Point 6: Adjustment complete after 8 steps, final log_likelihoods - usable=[-2.23337877], unusable=[-2.73999755]
# Point 7: Starting adjustment
# Point 7, Step 0: log_likelihood_usable=[-10.23133436], log_likelihood_unusable=[4.3176068]
# Point 7, Step 1: log_likelihood_usable=[-9.24080869], log_likelihood_unusable=[3.14507616]
# Point 7, Step 2: log_likelihood_usable=[-8.27031585], log_likelihood_unusable=[1.97867143]
# Point 7, Step 3: log_likelihood_usable=[-7.32045652], log_likelihood_unusable=[0.87285908]
# Point 7, Step 4: log_likelihood_usable=[-6.38227166], log_likelihood_unusable=[-0.18016898]
# Point 7, Step 5: log_likelihood_usable=[-5.44593765], log_likelihood_unusable=[-1.25075481]
# Point 7, Step 6: log_likelihood_usable=[-4.52432113], log_likelihood_unusable=[-2.36585166]
# Point 7, Step 7: log_likelihood_usable=[-3.62751823], log_likelihood_unusable=[-3.5246705]
# Point 7: Adjustment complete after 8 steps, final log_likelihoods - usable=[-2.76157556], unusable=[-4.68235206]
# Point 8: Starting adjustment
# Point 8, Step 0: log_likelihood_usable=[-12.90807958], log_likelihood_unusable=[5.34030116]
# Point 8, Step 1: log_likelihood_usable=[-11.54512014], log_likelihood_unusable=[3.91027065]
# Point 8, Step 2: log_likelihood_usable=[-10.24459871], log_likelihood_unusable=[2.59978378]
# Point 8, Step 3: log_likelihood_usable=[-9.05312013], log_likelihood_unusable=[1.39776053]
# Point 8, Step 4: log_likelihood_usable=[-7.97074963], log_likelihood_unusable=[0.17402366]
# Point 8, Step 5: log_likelihood_usable=[-6.95671329], log_likelihood_unusable=[-1.0818349]
# Point 8, Step 6: log_likelihood_usable=[-5.99099569], log_likelihood_unusable=[-2.33813438]
# Point 8, Step 7: log_likelihood_usable=[-5.06335617], log_likelihood_unusable=[-3.57183151]
# Point 8: Adjustment complete after 8 steps, final log_likelihoods - usable=[-4.16613899], unusable=[-4.79646821]
# Point 9: Starting adjustment
# Point 9, Step 0: log_likelihood_usable=[-17.23679581], log_likelihood_unusable=[5.98504003]
# Point 9, Step 1: log_likelihood_usable=[-15.78323269], log_likelihood_unusable=[4.55111421]
# Point 9, Step 2: log_likelihood_usable=[-14.3645313], log_likelihood_unusable=[3.0798594]
# Point 9, Step 3: log_likelihood_usable=[-12.98479985], log_likelihood_unusable=[1.59368391]
# Point 9, Step 4: log_likelihood_usable=[-11.6492051], log_likelihood_unusable=[0.12187847]
# Point 9, Step 5: log_likelihood_usable=[-10.3676538], log_likelihood_unusable=[-1.29980555]
# Point 9, Step 6: log_likelihood_usable=[-9.15996708], log_likelihood_unusable=[-2.63816944]
# Point 9, Step 7: log_likelihood_usable=[-8.04885623], log_likelihood_unusable=[-3.91997207]
# Point 9, Step 8: log_likelihood_usable=[-7.03051462], log_likelihood_unusable=[-5.20611048]
# Point 9: Adjustment complete after 9 steps, final log_likelihoods - usable=[-6.08137618], unusable=[-6.50486119]
# Point 10: Starting adjustment
# Point 10, Step 0: log_likelihood_usable=[-23.35499392], log_likelihood_unusable=[5.33518785]
# Point 10, Step 1: log_likelihood_usable=[-21.90346627], log_likelihood_unusable=[4.18500062]
# Point 10, Step 2: log_likelihood_usable=[-20.47091401], log_likelihood_unusable=[2.98724585]
# Point 10, Step 3: log_likelihood_usable=[-19.0602458], log_likelihood_unusable=[1.73820261]
# Point 10, Step 4: log_likelihood_usable=[-17.6744477], log_likelihood_unusable=[0.4380385]
# Point 10, Step 5: log_likelihood_usable=[-16.31627551], log_likelihood_unusable=[-0.91044247]
# Point 10, Step 6: log_likelihood_usable=[-14.98830802], log_likelihood_unusable=[-2.30051392]
# Point 10, Step 7: log_likelihood_usable=[-13.69287422], log_likelihood_unusable=[-3.71909392]
# Point 10, Step 8: log_likelihood_usable=[-12.43141166], log_likelihood_unusable=[-5.14741571]
# Point 10, Step 9: log_likelihood_usable=[-11.20382578], log_likelihood_unusable=[-6.57067885]
# Point 10: Did not converge within 10 steps, final log_likelihoods - usable=[-10.01097789], unusable=[-7.98312418]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Number of designs that are closer to usable with max_iter=5: 10
# Number of designs that are closer to usable with max_iter=10: 11

# %% [markdown]
# ### Compare interpolation methods in two dimension

# %% [markdown]
# ### Generate KDE-guided points

# %%
new_points = np.array(guided_points_all[5])
res=(tf.math.sigmoid(tuned_decoder.predict(new_points))).numpy()
indices=[f'kde_guided{i}' for i in range(len(new_points))]
meandf=pd.DataFrame(res, index=indices, columns=dfn.columns)
meandf.to_csv(f"../data/temp.csv")  # Saving to CSV

processGen.processGen(f"temp", denorm=True)
clear_output(wait=False)  # This clears the previous print output

# %% [markdown]
# ### Generate linearly interpolated points

# %%
res=(tf.math.sigmoid(tuned_decoder.predict(linear_interpolated_points))).numpy()
indices=[f'inter{i}' for i in range(len(linear_interpolated_points))]
meandf=pd.DataFrame(res, index=indices, columns=dfn.columns)
meandf.to_csv(f"../data/temp.csv")  # Saving to CSV
processGen.processGen(f"temp", denorm=True)
clear_output(wait=False)  # This clears the previous print output

# %%
plt.figure(figsize=(8, 6))
comp1 = 0
comp2 = 1

plt.plot(linear_interpolated_points[:, comp1], linear_interpolated_points[:, comp2], 'o-', label='Normal Interpolation')

if len(new_points) > 0:
    plt.plot(new_points[:, comp1], new_points[:, comp2], 'x-', label='KDE-guided Interpolation', color='r')

plt.title('Comparison of Normal and KDE-guided Interpolation')
plt.xlabel(f'Component {comp1}')
plt.ylabel(f'Component {comp2}')
plt.legend()
plt.grid(True)
plt.show()
